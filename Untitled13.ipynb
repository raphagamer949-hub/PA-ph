# %% [markdown]
# <a href="https://colab.research.google.com/github/raphagamer949-hub/PA-ph/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
aluno = {
    "nome": "PH",
    "idade": 15,
    "curso": "Informática"
}

print(aluno)

# %%
# 2
aluno = {
    "nome": "PH",
    "idade": 15,
    "curso": "Informática"
}

print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])

# %%
# 3
produto = {
    "nome": "Estojo",
    "preco": 20,
    "estoque": 50
}

produto["preco"] = 25

print(produto)

# %%
# 4
aluno = {
    "nome": "PH",
    "idade": 15
}

aluno["curso"] = "Informática"

print(aluno)

# %%
# 5
filme = {
    "titulo": "Homem Aranha",
    "ano": 2026,
    "genero": "Ação",
    "nota": 10
}

print(filme["titulo"])
print(filme["ano"])
print(filme["genero"])
print(filme["nota"])

# %%
#1

numeros = {1, 2, 3, 4, 5}

print(numeros)

# %%
# 3
frutas = {"maçã", "uva", "limao"}

frutas.add("abacate")

print(frutas)

# %%
# 4
cores = {"verde", "amarelo", "azul", "vermelho"}

cores.remove("roxo")

print(cores)

# %%
#5
nomes = ["ph", "murilo", "murilo", "Maitê", "ph", "Ravi", "Gael", "vanessa", "vanessa"]

nomes = set(nomes)

print(nomes)
