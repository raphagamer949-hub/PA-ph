# %% [markdown]
# <a href="https://colab.research.google.com/github/raphagamer949-hub/PA-ph/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

numero = int(input("Digite um número: "))

i = 1

while i <= numero:
    print(i)
    i += 1

# %%
#2

numero = int(input("Digite um número: "))

while numero >= 0:
    print(numero)
    numero -= 1

# %%
#3

numero = 0

while numero <= 20:
    print(numero)
    numero += 2

# %%
#4

numero = int(input("Digite um número: "))

soma = 0
i = 1

while i <= numero:
    soma += i
    i += 1

print("A soma é:", soma)

# %%
#5

numero = int(input("Digite um número: "))

i = 1

while i <= 10:
    resultado = numero * i
    print(f"{numero} x {i} = {resultado}")
    i += 1

# %%
#6

senha = input("Digite a senha: ")

while senha != "1234":
    print("Senha incorreta!")
    senha = input("Digite a senha: ")

print("Acesso permitido!")

# %%
#7

soma = 0

numero = int(input("Digite um número (0 para parar): "))

while numero != 0:
    soma += numero
    numero = int(input("Digite um número (0 para parar): "))

print("A soma dos números é:", soma)

# %%
#8

maior = None

numero = int(input("Digite um número (0 para parar): "))

while numero != 0:
    if maior is None or numero > maior:
        maior = numero

    numero = int(input("Digite um número (0 para parar): "))

if maior is not None:
    print("O maior número digitado foi:", maior)
else:
    print("Nenhum número foi digitado.")

# %%
#9

soma = 0
contador = 1

while contador <= 5:
    nota = float(input(f"Digite a {contador} nota: "))
    soma += nota
    contador += 1

media = soma / 5

print("A média das notas é:", media)

# %%
#10

saldo = 1000.00

while True:
    print("\n--- MENU ---")
    print("1 - Depositar")
    print("2 - Sacar")
    print("3 - Ver saldo")
    print("4 - Sair")

    opcao = int(input("Escolha uma opção: "))

    if opcao == 1:
        valor = float(input("Digite o valor do depósito: R$ "))
        saldo += valor
        print("Depósito realizado com sucesso!")

    elif opcao == 2:
        valor = float(input("Digite o valor do saque: R$ "))

        if valor <= saldo:
            saldo -= valor
            print("Saque realizado com sucesso!")
        else:
            print("Saldo insuficiente!")

    elif opcao == 3:
        print(f"Saldo atual: R$ {saldo:.2f}")

    elif opcao == 4:
        print("Programa encerrado!")
        break

    else:
        print("Opção inválida!")
