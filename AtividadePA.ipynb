# %% [markdown]
# <a href="https://colab.research.google.com/github/raphagamer949-hub/PA-ph/blob/main/AtividadePA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1

frutas = ["Maçã", "Banana", "Laranja", "Morango"]
print(frutas)

# %%
#2

nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])

# %%
#3

cores = ["Vermelho", "Azul", "Verde"]
cores[1] = "Amarelo"
print(cores)

# %%
#4

alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)

# %%
#5

animais = ["Cachorro", "Gato", "Coelho", "Passarinho"]
animais.remove("Coelho")
print(animais)

# %%
#Tuplas

#1

meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)

# %%
#2

numeros = (10,20,30,40,50)
print(numeros[0])
print(numeros[2])
print(numeros[4])

# %%
#3

aluno = ("Murilo", 15, "Informática")
print(aluno[0])
print(aluno[1])
print(aluno[2])

# %%
#4

cores = ("Vermelho", "Azul", "Verde")
cores[1] = "Amarelo"
#TypeError: 'tuple' object does not support item assignment

# %%
#5

numeros = (2,4,2,6,2,10)
print(numeros.count(2))
